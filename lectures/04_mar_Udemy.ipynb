# %% [markdown]
# <a href="https://colab.research.google.com/github/Kranthi98/Udemy-python-ML/blob/master/lectures/04_mar_Udemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a =np.random.random(5)*5
a
# Out:
# array([1.56656553, 2.06724071, 1.42807187, 3.75714969, 2.65832319])

# %%
b = np.array[range(1,6)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-8f7553d45deb> in <module>()
# ----> 1 b = np.array[range(1,6)]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ##dealing with images

# %%
from skimage import io

# %%
pic = io.imread("https://madhu.com/images/h500.gif")

# %%
plt.imshow(pic)

# %%
pic.shape
# Out:
# (301, 442, 4)

# %%
plt.imshow(pic[100:200,::-1])

# %% [markdown]
# ##assignment 11

# %%
x = np.array(range(1,6))
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
plt.plot(x,2*x,color = "red")
plt.title('simple line plot')
plt.xlabel('x')
plt.ylabel('2x')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##reshaping the data

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.reshape(1,6)
# Out:
# array([[1, 2, 3, 4, 5, 6]])

# %% [markdown]
# ##Tensorflow
# #####an activation function is must for a layer.,removing that it will be barely a linear function
# ####activation layer can be specified as layer or as a layer parameter
# ###1.as a layer

# %%
model.add(Activation('relu'))

# %% [markdown]
# ###2.as a layer parameter

# %%
model.add(Dense(128,Activation = 'relu'))

# %% [markdown]
# #####different types of activations functions
# #####--Rectified linear unit
# #####--Softmax
# #####--Sigmoid,TanH
# #####--Linear

# %% [markdown]
# ##ReLU:
# #####commonly used activation function
# ##Softmax:
# #####used at output layer for classification .Sum values for all outputs is 1.0
# ##TanH,Sigmoid:
# #####traditionally used for logistc regression.Sometimes used in hidden layers
# ##Linear (no Actuivation)
# #####used at output layer for numerical output
